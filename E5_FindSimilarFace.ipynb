# %% [markdown]
# # LMS Exploration | 5. AI measuring Similarity
#
# ---
#
# **[Introduce]**
# * 두 얼굴이 얼마나 닮았는지 유사도를 측정하는 AI 모델을 만들어보자
# * 이번시간에는 본인의 얼굴이 어떤 연예인과 닮았는지 유사도를 측정해볼 것이다.
# * 얼굴 이미지를 비교할 때, 고차원 정보를 저차원으로 변환하면서 필요한 정보를 보존하는 **임베딩 기법**을 활용할 수 있다.
#
# **[Data]**
# * 내얼굴 4장(무표정, 피곤한표정, 살짝웃는표정, 빵긋웃는표정으로 다양하게 준비했음)
# * 연예인 사진 283장 (남녀노소, 배우, 가수, 개그맨, 운동선수 등 다양함)
#
# **[Preparation]**
# * tar.xz 압축파일을 현재 폴더에 푸는 코드 : tar -xvf파일이름.tar.xz

# %% [markdown]
# ---
#
# ## 1. Preparation

# %% [markdown]
# ### 1-1. 이미지 파일 준비하기
# * 내 얼굴과 유사도를 측정할 연예인 폴더의 압축을 풀어줍니다.
#     다양한 연예인 이미지를 제공해주신 수희님께 감사드립니다 :)
#
#
# ```os
# root@wb3olflparel9bwqagowzdzvt-55c9b997cb-ptb57:~/aiffel/SimilarFace# tar - xvfcelebrity.tar.xz
#
# celebrity/
# celebrity/윤균상.jpg
# celebrity/이종석.jpeg
# celebrity/박해일.jpeg
# celebrity/이승철.jpeg
# ```

# %% [markdown]
# ### 1-2. 파일 확장자 변환
# * 파일 사용을 용이하게 하기 위해서 jpeg, jpg, png로 다양했던 확장자를 모두 jpg로 변환해주었습니다.
#
#
# ```python
# import glob
#
# files = glob.glob(dir_path+'/celebrity/*')
#
# for name in files:
#     print(name)
#     if not os.path.isdir(name):
#         src = os.path.splitext(name)
#         os.rename(name, src[0]+'.jpg')
# ```

# %%
#- 필요한 라이브러리 불러오기
import os
import face_recognition
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline

# %% [markdown]
# ## 2. define function | 함수 정의하기

# %% [markdown]
# * **face_recognition.api.load_image_file(file, mode='RGB')**
# Loads an image file (.jpg, .png, etc) into a numpy array
# Returns : image contents as numpy array
# * **face_recognition.api.face_locations(img, number_of_times_to_upsample=1, model='hog')**
# Returns an array of bounding boxes of human faces in a image
# Returns : A list of tuples of found face locations in css (top, right, bottom, left) order
#
# 참고 : [face_recognition](https://face-recognition.readthedocs.io/en/latest/face_recognition.html)

# %% [markdown]
# ### 2-1. detect & crop face

# %%
#- 임베딩 추출을 위해 얼굴 영역을 자르는 함수
#- cropped_face는 PIL 이미지로 변환하여 저장

def get_cropped_face(image_file): 
    
    image = face_recognition.load_image_file(image_file) #- 넘파이 배열로 이미지 로드
    face_locations = face_recognition.face_locations(image) #- 얼굴 영역의 넘파이 배열 반환
    a, b, c, d = face_locations[0]
    cropped_face = image[a:c,d:b,:]
    
    return cropped_face

# %% [markdown]
# * face detection이 잘 이루어지지 않는 경우에 발생하는 오류 처리하기
#
# face detection이 잘 이뤄지지 않는 경우, face_locations 변수에는 빈 튜플리스트가 저장되고, get_face_embedding함수에서 오류가 나게됩니다. 이러한 오류 문제를 해결하기 위한 방법에는 여러가지가 있습니다.
#
#
#     채택한 방법 : get_face_embedding_dict 함수에서 try-except 문을 활용하여 get_face_embadding 함수에서 오류가 나는 경우엔 예외처리로 pass를 설정합니다.
#
#     첫번째 방법 : face_locations=[(0,0,0,0)] 할당
#     두번째 방법 : 그 이미지 지우기
#     세번째 방법 : face_locations 의 평균을 넣기 << 얼굴 위치가 제각각이어서 의미 없음

# %% [markdown]
# ### 2-2. face embedding

# %%
def get_face_embedding(face):
    return face_recognition.face_encodings(face)


def get_face_embedding_dict(dir_path):
    file_list = os.listdir(dir_path)
    embedding_dict = {}
     
    for file in file_list:
        img_path = os.path.join(dir_path, file)
        try:
            face = get_cropped_face(img_path)
            embedding = get_face_embedding(face)
            if len(embedding) > 0:  #- face detection이 잘 이뤄지지 않은 부분은 제외합니다. 
                embedding_dict[os.path.splitext(file)[0]] = embedding[0] #- 임베딩 사전에는 확장자를 제거한 파일이름을 저장합니다.
        except:
            pass
       
    return embedding_dict

# %% [markdown]
# ### 2-3. Similarity

# %%
def get_distance(name1, name2): 
    return np.linalg.norm(embedding_dict[name1]-embedding_dict[name2], ord=2)

def get_sort_key_func(name1):
    def get_distance_from_name1(name2):
        return get_distance(name1, name2)
    return get_distance_from_name1

def get_nearest_face(name, top=5):
    sort_key_func = get_sort_key_func(name)
    sorted_faces = sorted(embedding_dict.items(), key=lambda x:sort_key_func(x[0]))
    similar_face = {}
    for i in range(top+1):
        if i == 0 :   #- 첫번째로 나오는 이름은 자기 자신일 것이므로 제외합니다. 
            continue
        if sorted_faces[i]:
            print('순위 {} : 이름({}), 거리({})'.format(i, sorted_faces[i][0], sort_key_func(sorted_faces[i][0])))
            similar_face[sorted_faces[i][0]] = sort_key_func(sorted_faces[i][0]) 
    return similar_face

# %%
import cv2
def show_nearest_face(similar_face):
    fig = plt.figure()
    rows = 3
    cols = 2
    for i,(j,k) in enumerate(similar_face.items()):
        if i == 0:
            continue
            
        img = plt.imread(dir_path+'/celebrity/'+j+'.jpg')   
        ax = fig.add_subplot(rows, cols, i)
        ax.set_title(f'김은서와 {i}번째로 닮은 연예인은 {j}입니다')
        ax.axis('off')
        plt.show()
        fig.tight_layout()

# %% [markdown]
# ## 2. face recognition | 얼굴인식
# * 얼굴 임베딩을 구하기에 앞서, 이미지 속에서 얼굴 영역만을 정확히 인식하여 추출해 내야 합니다.
# * 이를 통해 얼굴의 특성을 반영하는 임베딩 벡터를 정확히 얻을 수 있습니다.
# * face_recognition 라이브러리를 불러와서 load image, detect face, crop face 등 다양한 메서드를 활용해보겠습니다~

# %%
dir_path = os.getenv('HOME')+'/aiffel/SimilarFace' #- 내얼굴 이미지파일이 들어있는 폴더
file_list = os.listdir(dir_path+'/me') #- 내얼굴 이미지파일 리스트 

print ("file_list: {}".format(file_list)) #- 불러온 파일 리스트 확인

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(7,10))

for i, ax in enumerate(axes.flatten()): #- 파일 이미지 확인하기
    image = face_recognition.load_image_file(dir_path+'/me/'+file_list[i])
    ax.imshow(image)

plt.show()
fig.tight_layout()
# Out:
# file_list: ['김은서0.jpg', '김은서3.jpg', '김은서1.jpg', '김은서2.jpg']

# %% [markdown]
# ## 3. detect & crop & embed face

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(7,7))

for i, ax in enumerate(axes.flatten()):
    cropped_face = get_cropped_face(dir_path+'/me/'+file_list[i])
    ax.imshow(cropped_face)
    
    #- cropped_face를 PIL 이미지로 변환하여 저장하기
    pillow_image = Image.fromarray(cropped_face) 
    
    pillow_image.save(dir_path+'/my_cropped_face/'+file_list[i])    
    print("{} 저장완료!".format(dir_path+'/my_cropped_face/'+file_list[i]))
    
    #- 얼굴 영역의 임베딩 추출하기
embedding = get_face_embedding(cropped_face)
embedding_dict = get_face_embedding_dict(dir_path+'/me')
# Out:
# /aiffel/aiffel/SimilarFace/my_cropped_face/김은서0.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/my_cropped_face/김은서3.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/my_cropped_face/김은서1.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/my_cropped_face/김은서2.jpg 저장완료!

# %% [markdown]
# ## 4. 유사도 측정하기

# %%
get_nearest_face('김은서0', 3)
# Out:
# 순위 1 : 이름(김은서3), 거리(0.16834623852432945)
# 순위 2 : 이름(김은서1), 거리(0.2397428642290488)
# 순위 3 : 이름(김은서2), 거리(0.3114067749831206)
# {'김은서3': 0.16834623852432945,
#  '김은서1': 0.2397428642290488,
#  '김은서2': 0.3114067749831206}

# %% [markdown]
# ## 5. 본격 ! 내 얼굴이 어떤 연예인과 닮았는지 알아보기

# %% [markdown]
# ### 5-1. preparation

# %%
dir_path = os.getenv('HOME')+'/aiffel/SimilarFace' 
file_list = os.listdir(dir_path+'/celebrity') #- 연예인 이미지파일 리스트 
print ("file_list: {}".format(file_list)) #- 불러온 파일 리스트 확인
# Out:
# file_list: ['김상호.jpg', '벤 에플렉.jpg', '이대형.jpg', '이근대위.jpg', '이명박.jpg', '이희준.jpg', '류승범.jpg', '유재석.jpg', '손흥민.jpg', '매드클라운.jpg', '홍구.jpg', '곽도원.jpg', '박찬호.jpg', '손예진.jpg', '디오.jpg', '도아.jpg', '정수빈.jpg', '티파니.jpg', '최민식.jpg', '박보검.jpg', '박완규.jpg', '윤균상.jpg', '리암 니슨.jpg', '박휘순.jpg', '이범수.jpg', '정국.jpg', '신태용.jpg', '효정.jpg', '사쿠라.jpg', '찬열.jpg', '크리스 에반스.jpg', '티모시 달튼.jpg', '박보영.jpg', '로저 무어.jpg', '솔라.jpg', '황병국.jpg', '시우민.jpg', '존 파브르.jpg', '류승룡.jpg', '잭 니콜슨.jpg', '이진호.jpg', '정형돈.jpg', '차명석.jpg', '박나래.jpg', '전소미.jpg', '무라니시.jpg', '레드벨벳웬디.jpg', '윤종신.jpg', '이말년.jpg', '첸.jpg', '슬리피.jpg', '신동엽.jpg', '트와이스나연.jpg', '김고은.jpg', '슈가.jpg', '이승철.jpg', '슈퍼비.jpg', '이성민.jpg', '트와이스다현.jpg', '다니엘 크레이그.jpg', '잇섭.jpg', '이천수.jpg', '브래들리 쿠퍼.jpg', '러블리즈예인.jpg', '주진모(올드).jpg', '유노윤호.jpg', '도지한.jpg', '잇지유나.jpg', '김종서.jpg', '윤도현.jpg', '이영하.jpg', '손호준.jpg', '톰 홀랜드.jpg', '켄 정.jpg', '대도서관.jpg', '신비.jpg', '줄리엔강.jpg', '김민재.jpg', '길.jpg', '조이.jpg', '로제.jpg', '민니.jpg', '이승환.jpg', '장도연.jpg', '유해진.jpg', '아이즈원민주.jpg', '조승우.jpg', '이제훈.jpg', '정준하.jpg', '앤드류 응.jpg', '조인성.jpg', '지호.jpg', 'clinton.jpg', '이동휘.jpg', '나인뮤지스경리.jpg', '최무성.jpg', 'rename.jpg', '세훈.jpg', '케이.jpg', '조정석.jpg', '아이린.jpg', '이재용.jpg', '우기.jpg', '개리.jpg', '옥냥이.jpg', '아이유.jpg', '장원준.jpg', '강동원.jpg', '서장훈.jpg', '김구라.jpg', '리아.jpg', '트와이스모모.jpg', '성룡.jpg', '아이즈원김채원.jpg', '돈스파이크.jpg', '러블리즈지수.jpg', '김래원.jpg', '조정치.jpg', '지수.jpg', '화사.jpg', '박서준.jpg', '박건우.jpg', '미미.jpg', '박찬욱.jpg', '김희철.jpg', '박진영.jpg', '드웨인 존슨.jpg', '이동국.jpg', '윤아.jpg', '배성재.jpg', '제이크 질렌할.jpg', 'bush.jpg', 'b1a4진영.jpg', '이민호.jpg', '숀 코네리.jpg', '박용택.jpg', '클린트 이스트우드.jpg', '잇지예지.jpg', '아린.jpg', '김대중.jpg', '꽈두룹.jpg', '비니.jpg', '철면수심.jpg', '김은서0.jpg', '하정우.jpg', '박해일.jpg', '여자아이들수진.jpg', '강민경.jpg', '이승기.jpg', '제이콥 배털론.jpg', '서현진.jpg', '김윤석.jpg', '딕헌터.jpg', '김영삼.jpg', '온앤오프라운.jpg', '이정재.jpg', '김연우.jpg', '박항서.jpg', '이안 굿펠로우.jpg', '김C.jpg', '승희.jpg', '김현수.jpg', '온앤오프와이엇.jpg', '박명수.jpg', '트와이스정연.jpg', '제이홉.jpg', '백현.jpg', '목진화.jpg', '아이즈원조유리.jpg', '주호민.jpg', '장원영.jpg', '잭 갤리퍼내키스.jpg', '조원희.jpg', '고창석.jpg', '사무엘 L 잭슨.jpg', '성시경.jpg', '김학범.jpg', '케빈 스페이시.jpg', '노홍철.jpg', '슬기.jpg', '류준열.jpg', '박성호.jpg', '이광수.jpg', '잭 스페이더.jpg', '김대명.jpg', '야마다 타카유키.jpg', '태양.jpg', '노무현.jpg', '트와이스쯔위.jpg', '트와이스사나.jpg', '잭 블랙.jpg', '오재원.jpg', '아놀드 슈워제네거.jpg', '스윙스.jpg', '이연걸.jpg', '지드래곤.jpg', '공효진.jpg', '지디.jpg', '서강준.jpg', '문별.jpg', '유희열.jpg', '장동건.jpg', '피어스 브로스넌.jpg', '조달환.jpg', '송중기.jpg', '영알남.jpg', '백윤식.jpg', '안재홍.jpg', '공유.jpg', '윤경신.jpg', '봉준호.jpg', '제프리 힌턴.jpg', '한효주.jpg', '이경규.jpg', '이용진.jpg', '지코.jpg', '이대호.jpg', '최현석.jpg', '차범근.jpg', '류진.jpg', '유리.jpg', '황정민.jpg', '산들.jpg', '정우성.jpg', '이종석.jpg', '류현진.jpg', '하승진.jpg', '박희순.jpg', '레오나르도 디카프리오.jpg', '이효리.jpg', '한석규.jpg', '김광현.jpg', '장성호.jpg', '심수창.jpg', '수지.jpg', '레인보우재경.jpg', 'biden.jpg', '하현우.jpg', '이준혁.jpg', '트와이스미나.jpg', '크리스탈.jpg', '차두리.jpg', '배성우.jpg', '뷔.jpg', '카이.jpg', '한기범.jpg', '택연.jpg', '강미나.jpg', '진.jpg', '크리스 햄스워스.jpg', '로다주.jpg', '정민철.jpg', '김남주.jpg', '문재인.jpg', '수호.jpg', '채연.jpg', '권현빈.jpg', '김유정.jpg', '차승원.jpg', '마크 러팔로.jpg', '제니.jpg', '태연.jpg', '최준석.jpg', '마동석.jpg', '기성용.jpg', '김경진.jpg', '최양락.jpg', '개코.jpg', '박정민.jpg', '유지태.jpg', '박재범.jpg', 'RM.jpg', '온앤오프효진.jpg', '리사.jpg', '유아.jpg', '박신양.jpg', '권태원.jpg', 'trump.jpg', 'obama.jpg', '저스틴 존슨.jpg', '씨잼.jpg', '지민(BTS).jpg', '방시혁.jpg']

# %% [markdown]
# ### 5-2. load images

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10,10))

for i, ax in enumerate(axes.flatten()): #- 파일 이미지 확인하기
    image = face_recognition.load_image_file(dir_path+'/celebrity/'+file_list[i])
    
    ax.imshow(image)

plt.show()
fig.tight_layout()

# %%
print(len(file_list))
# Out:
# 283

# %% [markdown]
# ### 5-3. detect & crop & embed face

# %%
for i, file in enumerate(file_list):
    try:
        cropped_face = get_cropped_face(dir_path+'/celebrity/'+file)
        pillow_image = Image.fromarray(cropped_face) 
    
        pillow_image.save(dir_path+'/cropped_face/'+file)    
        print("{} 저장완료!".format(dir_path+'/cropped_face/'+file))
    
    except: 
              print(i, file)

embedding_dict = get_face_embedding_dict(dir_path+'/celebrity')
# Out:
# /aiffel/aiffel/SimilarFace/cropped_face/김상호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/벤 에플렉.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이대형.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이근대위.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이명박.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이희준.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/류승범.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/유재석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/손흥민.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/매드클라운.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/홍구.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/곽도원.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박찬호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/손예진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/디오.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/도아.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/정수빈.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/티파니.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/최민식.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박보검.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박완규.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/윤균상.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/리암 니슨.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박휘순.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이범수.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/정국.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/신태용.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/효정.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/사쿠라.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/찬열.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/크리스 에반스.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/티모시 달튼.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박보영.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/로저 무어.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/솔라.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/황병국.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/시우민.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/존 파브르.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/류승룡.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/잭 니콜슨.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이진호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/정형돈.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/차명석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박나래.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/전소미.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/무라니시.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/레드벨벳웬디.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/윤종신.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이말년.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/첸.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/슬리피.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/신동엽.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/트와이스나연.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김고은.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/슈가.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이승철.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/슈퍼비.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이성민.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/트와이스다현.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/다니엘 크레이그.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/잇섭.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이천수.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/브래들리 쿠퍼.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/러블리즈예인.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/주진모(올드).jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/유노윤호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/도지한.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/잇지유나.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김종서.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/윤도현.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이영하.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/손호준.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/톰 홀랜드.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/켄 정.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/대도서관.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/신비.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/줄리엔강.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김민재.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/길.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/조이.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/로제.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/민니.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이승환.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/장도연.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/유해진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/아이즈원민주.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/조승우.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이제훈.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/정준하.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/앤드류 응.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/조인성.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/지호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/clinton.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이동휘.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/나인뮤지스경리.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/최무성.jpg 저장완료!
# 96 rename.jpg
# /aiffel/aiffel/SimilarFace/cropped_face/세훈.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/케이.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/조정석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/아이린.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이재용.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/우기.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/개리.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/옥냥이.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/아이유.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/장원준.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/강동원.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/서장훈.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김구라.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/리아.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/트와이스모모.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/성룡.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/아이즈원김채원.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/돈스파이크.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/러블리즈지수.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김래원.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/조정치.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/지수.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/화사.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박서준.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박건우.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/미미.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박찬욱.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김희철.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박진영.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/드웨인 존슨.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이동국.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/윤아.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/배성재.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/제이크 질렌할.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/bush.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/b1a4진영.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이민호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/숀 코네리.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박용택.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/클린트 이스트우드.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/잇지예지.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/아린.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김대중.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/꽈두룹.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/비니.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/철면수심.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김은서0.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/하정우.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박해일.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/여자아이들수진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/강민경.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이승기.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/제이콥 배털론.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/서현진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김윤석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/딕헌터.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김영삼.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/온앤오프라운.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이정재.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김연우.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박항서.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이안 굿펠로우.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김C.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/승희.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김현수.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/온앤오프와이엇.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박명수.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/트와이스정연.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/제이홉.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/백현.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/목진화.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/아이즈원조유리.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/주호민.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/장원영.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/잭 갤리퍼내키스.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/조원희.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/고창석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/사무엘 L 잭슨.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/성시경.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김학범.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/케빈 스페이시.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/노홍철.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/슬기.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/류준열.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박성호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이광수.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/잭 스페이더.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김대명.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/야마다 타카유키.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/태양.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/노무현.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/트와이스쯔위.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/트와이스사나.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/잭 블랙.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/오재원.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/아놀드 슈워제네거.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/스윙스.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이연걸.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/지드래곤.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/공효진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/지디.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/서강준.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/문별.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/유희열.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/장동건.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/피어스 브로스넌.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/조달환.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/송중기.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/영알남.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/백윤식.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/안재홍.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/공유.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/윤경신.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/봉준호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/제프리 힌턴.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/한효주.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이경규.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이용진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/지코.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이대호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/최현석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/차범근.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/류진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/유리.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/황정민.jpg 저장완료!
# 222 산들.jpg
# /aiffel/aiffel/SimilarFace/cropped_face/정우성.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이종석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/류현진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/하승진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박희순.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/레오나르도 디카프리오.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이효리.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/한석규.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김광현.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/장성호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/심수창.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/수지.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/레인보우재경.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/biden.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/하현우.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/이준혁.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/트와이스미나.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/크리스탈.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/차두리.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/배성우.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/뷔.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/카이.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/한기범.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/택연.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/강미나.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/크리스 햄스워스.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/로다주.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/정민철.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김남주.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/문재인.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/수호.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/채연.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/권현빈.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김유정.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/차승원.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/마크 러팔로.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/제니.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/태연.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/최준석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/마동석.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/기성용.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/김경진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/최양락.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/개코.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박정민.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/유지태.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박재범.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/RM.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/온앤오프효진.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/리사.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/유아.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/박신양.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/권태원.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/trump.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/obama.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/저스틴 존슨.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/씨잼.jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/지민(BTS).jpg 저장완료!
# /aiffel/aiffel/SimilarFace/cropped_face/방시혁.jpg 저장완료!

# %% [markdown]
# ### 5-5. 나와 가장 닮은 연예인은??

# %%
my_nearest_face = get_nearest_face('김은서0', 5)
# Out:
# 순위 1 : 이름(정수빈), 거리(0.3656937945663996)
# 순위 2 : 이름(유리), 거리(0.3926421238091161)
# 순위 3 : 이름(박건우), 거리(0.3932206126565758)
# 순위 4 : 이름(정준하), 거리(0.39803343591287443)
# 순위 5 : 이름(안재홍), 거리(0.40335474688675055)

# %% [markdown]
# ## 6. 유사도 측정 시각화하기
